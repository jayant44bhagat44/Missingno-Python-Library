# %% [markdown]
# ### Visualize missing values (NaN) values using Missingno Library

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %%
# !pip install missingno

# %%
data=pd.read_csv(r"C:\Users\HP\Downloads\flats.csv")
import missingno as msno

# %% [markdown]
# ### Mising Value distribution acroos columns

# %%
msno.matrix(data);

# %% [markdown]
# ### Missing value barchart

# %%
msno.bar(data);

# %% [markdown]
# ### Heatmap of Dataset

# %%
msno.heatmap(data);
